# %%
import collections
import matplotlib.pyplot as plt
import networkx as nx
import pandas as pd
from collections import Counter
import seaborn as sns

# %%
G = nx.read_edgelist('../Data/Interactome/huri_apid_merge_ppis_edgelist.csv')

# %%
degree_sequence = sorted([d for n, d in G.degree()], reverse=True)

df_degree = pd.DataFrame(degree_sequence)

df_degree.hist(bins=20)
plt.title('Node degree distribution')
plt.xlabel('Node degree')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df_degree[df_degree[0] < 21].hist(bins=20)
plt.title('Node degree distribution (degree < 21)')
plt.xlabel('Node degree')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
print(df_degree.mean())
# Out:
# 0    14.564697
# dtype: float64

# %%
print(max(df_degree[0]))
print(min(df_degree[0]))
# Out:
# 678
# 1

# %%
components = list(nx.connected_components(G))
print(len(components))
Counter([len(x) for x in components]).most_common()
# Out:
# 65
# [(1, 44), (2, 18), (15277, 1), (4, 1), (3, 1)]
