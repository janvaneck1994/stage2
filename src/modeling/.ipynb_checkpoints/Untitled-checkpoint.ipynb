# %%
import torch
from datasets.Interactomes import Interactomes
import numpy as np

from utils.train_test_split_edges_fair import train_test_split_edges_fair

torch.manual_seed(12345)

dataset = Interactomes('../../Data/interactomes/human/', 'human')
data = dataset[0]

# %%
data
# Out:
# Data(edge_index=[2, 209198], protein_names=[1], x=[14068, 1024])

# %%
edges = np.array(list(set([tuple(sorted(x)) for x in edges]))).T

# %%
row, col = edges
mask = row < col
row, col = row[mask], col[mask]

# %%
print(len(set([(x[0], x[1]) for x in edges[:,:mask]])))
print(len([(x[0], x[1]) for x in edges[:,:mask]]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-100-6f3d670ac48e> in <module>
# ----> 1 print(len(set([(x[0], x[1]) for x in edges[:mask,:]])))
#       2 print(len([(x[0], x[1]) for x in edges[:mask,:]]))
#
# TypeError: only integer scalar arrays can be converted to a scalar index

# %%
len(edges[mask])
# Out:
# 104124

# %%
len(set([tuple(sorted(x)) for x in edges[mask]]))
# Out:
# 52062

# %%
already_seen = []
for x in edges[mask]:
    if tuple(x) in already_seen: 
        print(tuple(x))
    else:
        already_seen.append(tuple(x))
# Out:
# (6750, 3680)
# (11454, 3346)
# (13596, 7312)
# (13782, 3086)
# (11293, 1393)
# (10495, 8699)
# (9986, 1918)
# (10709, 7064)
# (12716, 9945)
# (3571, 933)
# (7447, 7375)
# (6070, 3742)
# (9754, 6377)
# (11622, 4159)
# (13992, 10147)
# (11656, 8975)
# (11338, 7095)
# (3461, 1990)
# (9694, 1336)
# (7271, 2934)
# (11654, 9534)
# (8980, 193)
# (13223, 12278)
# (7312, 4149)
# (12303, 5380)
# (13229, 8709)
# (1361, 610)
# (10034, 7797)
# (10836, 3213)
# (3458, 125)
# (4540, 4066)
# (12705, 11796)
# (9231, 8304)
# (12067, 11518)
# (9109, 561)
# (7786, 6022)
# (12616, 4028)
# (275, 4)
# (8212, 1241)
# (10034, 561)
# (11258, 1363)
# (13388, 12083)
# (10582, 7064)
# (7650, 2372)
# (6750, 2606)
# (13050, 11211)
# (6001, 2872)
# (11437, 2503)
# (10170, 8040)
# (6220, 167)
# (12051, 8592)
# (12733, 4146)
# (11557, 363)
# (8074, 365)
# (10517, 1038)
# (212, 4)
# (13905, 6102)
# (10762, 10527)
# (5759, 124)
# (2074, 261)
# (4386, 2860)
# (11855, 9597)
# (12835, 9460)
# (7967, 457)
# (7511, 4201)
# ...

# %%
neg_adj_mask = torch.ones(30, 30, dtype=torch.uint8)
neg_adj_mask = neg_adj_mask.triu(diagonal=1).to(torch.bool)
# neg_adj_mask[row, col] = 0

# %%
neg_adj_mask
# Out:
# tensor([[False,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#           True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#           True,  True,  True,  True,  True,  True,  True,  True,  True,  True],
#         [False, False,  True,  True,  True,  True,  True,  True,  True,  True,
#           True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#           True,  True,  True,  True,  True,  True,  True,  True,  True,  True],
#         [False, False, False,  True,  True,  True,  True,  True,  True,  True,
#           True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#           True,  True,  True,  True,  True,  True,  True,  True,  True,  True],
#         [False, False, False, False,  True,  True,  True,  True,  True,  True,
#           True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#           True,  True,  True,  True,  True,  True,  True,  True,  True,  True],
# ...
